# %% [markdown]
# # QGS model: Atmospheric model with heat exchange
# ## Li et al. 2017 model version
# This model version is a simple 2-layer channel QG atmosphere truncated at wavenumber 2 on a beta-plane with a simple orography (a montain and a valley) , with a radiative and heat exchanges scheme inspired by the MAOOAM model.
#
# More detail can be found in the articles:
# * Li, D., He, Y., Huang, J., Bi, L., & Ding, L. (2018). *Multiple equilibria in a land–atmosphere coupled system.* Journal of Meteorological Research, **32**(6), 950-973.
# [doi:10.1007/s13351-018-8012-y](https://doi.org/10.1007/s13351-018-8012-y)
# * De Cruz, L., Demaeyer, J. and Vannitsem, S. (2016). *The Modular Arbitrary-Order Ocean-Atmosphere Model: MAOOAM v1.0*, Geosci. Model Dev., **9**, 2793-2808. [doi:10.5194/gmd-9-2793-2016](https://doi.org/10.5194/gmd-9-2793-2016)
#
# or in the documentation.
#
# ## Modules import
# First, setting the path and loading of some modules

# %%
import sys, os

# %%
sys.path.extend([os.path.abspath('../')])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from matplotlib import rc
rc('font',**{'family':'serif','sans-serif':['Times'],'size':14})

# %% [markdown]
# Initializing the random number generator (for reproducibility). -- Disable if needed.

# %%
np.random.seed(210217)

# %% [markdown]
# Importing the model's modules

# %%
from qgs.params.params import QgParams
from qgs.integrators.integrator import RungeKuttaIntegrator, RungeKuttaTglsIntegrator
from qgs.functions.tendencies import create_tendencies
from qgs.plotting.util import std_plot

# %% [markdown]
# and diagnostics

# %%
from qgs.diagnostics.streamfunctions import MiddleAtmosphericStreamfunctionDiagnostic
from qgs.diagnostics.variables import VariablesDiagnostic
from qgs.diagnostics.multi import MultiDiagnostic

# %% [markdown]
# ## Systems definition
# General parameters. I am selecting standard parameters for the runs below, not sure if this is what Robin is using

# %%
# Time parameters
dt = 0.1
# Saving the model state n steps
write_steps = 5

number_of_trajectories = 1
number_of_perturbed_trajectories = 10

# %% [markdown]
# The other parameters can come from model1.pickle that Robin prepared:

# %%
import pickle
# loading the model
with open('model1.pickle', "rb") as file:
    model = pickle.load(file)

f = model['f']
Df = model['Df']
model_parameters = model['parameters']
# Printing the model's parameters
model_parameters.print_params()
# Out:
# Qgs v0.2.5 parameters summary
# =============================
#
# General Parameters:
# 'time_unit': days,
# 'rr': 287.058  [J][kg^-1][K^-1]  (gas constant of dry air),
# 'sb': 5.67e-08  [J][m^-2][s^-1][K^-4]  (Stefan-Boltzmann constant),
#
# Scale Parameters:
# 'scale': 5000000.0  [m]  (characteristic space scale (L*pi)),
# 'f0': 0.0001032  [s^-1]  (Coriolis parameter at the middle of the domain),
# 'n': 0.353    (aspect ratio (n = 2 L_y / L_x)),
# 'rra': 6370000.0  [m]  (earth radius),
# 'phi0_npi': 0.25    (latitude expressed in fraction of pi),
# 'deltap': 50000.0  [Pa]  (pressure difference between the two atmospheric layers),
#
# Atmospheric Parameters:
# 'kd': 0.1  [nondim]  (atmosphere bottom friction coefficient),
# 'kdp': 0.01  [nondim]  (atmosphere internal friction coefficient),
# 'sigma': 0.2  [nondim]  (static stability of the atmosphere),
#
# Atmospheric Temperature Parameters:
# 'gamma': 10000000.0  [J][m^-2][K^-1]  (specific heat capacity of the atmosphere),
# 'C[1]': 112.0  [W][m^-2]  (spectral component 1 of the short-wave radiation of
# 'C[30]': 0.0  [W][m^-2]  (spectral component 30 of the short-wave radiation of the atmosphere),
# 'C[31]': 0.0  [W][m^-2]  (spectral component 31 of the short-wave radiation of the atmosphere),
# 'C[32]': 0.0  [W][m^-2]  (spectral component 32 of the short-wave radiation of the atmosphere),
# 'C[33]': 0.0  [W][m^-2]  (spectral component 33 of the short-wave radiation of the atmosphere),
# 'C[34]': 0.0  [W][m^-2]  (spectral component 34 of the short-wave radiation of the atmosphere),
# 'C[35]': 0.0  [W][m^-2]  (spectral component 35 of the short-wave radiation of the atmosphere),
# 'C[36]': 0.0  [W][m^-2]  (spectral component 36 of the short-wave radiation of the atmosphere),
# 'eps': 0.76    (emissivity coefficient for the grey-body atmosphere),
# 'T0': 270.0  [K]  (stationary solution for the 0-th order atmospheric temperature),
# 'sc': 1.0    (ratio of surface to atmosphere temperature),
# 'hlambda': 20.0  [W][m^-2][K^-1]  (sensible+turbulent heat exchange between ocean and atmosphere),
#
# Ground Parameters:
# 'hk[1]': 0.0    (spectral component 1 of the orography),
# 'hk[2]': 0.4    (spectral components 2 of the orography),
# 'hk[3]': 0.0    (spectral component 3 of the orography),
# 'hk[4]': 0.0    (spectral component 4 of the orography),
# 'hk[5]': 0.0    (spectral component 5 of the orography),
# 'hk[6]': 0.0    (spectral component 6 of the orography),
# 'hk[7]': 0.0    (spectral component 7 of the orography),
# 'hk[8]': 0.0    (spectral component 8 of the orography),
# 'hk[9]': 0.0    (spectral component 9 of the orography),
# 'hk[10]': 0.0    (spectral component 10 of the orography),
# 'hk[11]': 0.0    (spectral component 11 of the orography),
# 'hk[12]': 0.0    (spectral component 12 of the orography),
# 'hk[13]': 0.0    (spectral component 13 of the orography),
# 'hk[14]': 0.0    (spectral component 14 of the orography),
# 'hk[15]': 0.0    (spectral component 15 of the orography),
# 'hk[16]': 0.0    (spectral component 16 of the orography),
# 'hk[17]': 0.0    (spectral component 17 of the orography),
# 'hk[18]': 0.0    (spectral component 18 of the orography),
# 'hk[19]': 0.0    (spectral component 19 of the orography),
# 'hk[20]': 0.0    (spectral component 20 of the orography),
# 'hk[21]': 0.0    (spectral component 21 of the orography),
# 'hk[22]': 0.0    (spectral component 22 of the orography),
# 'hk[23]': 0.0    (spectral component 23 of the orography),
# 'hk[24]': 0.0    (spectral component 24 of the orography),
# 'hk[25]': 0.0    (spectral component 25 of the orography),
# 'hk[26]': 0.0    (spectral component 26 of the orography),
# 'hk[27]': 0.0    (spectral component 27 of the orography),
# 'hk[28]': 0.0    (spectral component 28 of the orography),
# 'hk[29]': 0.0    (spectral component 29 of the orography),
# 'hk[30]': 0.0    (spectral component 30 of the orography),
# 'hk[31]': 0.0    (spectral component 31 of the orography),
# 'hk[32]': 0.0    (spectral component 32 of the orography),
# 'hk[33]': 0.0    (spectral component 33 of the orography),
# 'hk[34]': 0.0    (spectral component 34 of the orography),
# 'hk[35]': 0.0    (spectral component 35 of the orography),
# 'hk[36]': 0.0    (spectral component 36 of the orography),
# 'orographic_basis': atmospheric,
#
# Ground Temperature Parameters:
# 'gamma': 200000000.0  [J][m^-2][K^-1]  (specific heat capacity of the ground),
# 'C[1]': 280.0  [W][m^-2]  (spectral component 1 of the short-wave radiation of
# 'C[31]': 0.0  [W][m^-2]  (spectral component 31 of the short-wave radiation of the ground),
# 'C[32]': 0.0  [W][m^-2]  (spectral component 32 of the short-wave radiation of the ground),
# 'C[33]': 0.0  [W][m^-2]  (spectral component 33 of the short-wave radiation of the ground),
# 'C[34]': 0.0  [W][m^-2]  (spectral component 34 of the short-wave radiation of the ground),
# 'C[35]': 0.0  [W][m^-2]  (spectral component 35 of the short-wave radiation of the ground),
# 'C[36]': 0.0  [W][m^-2]  (spectral component 36 of the short-wave radiation of the ground),
# 'T0': 285.0  [K]  (stationary solution for the 0-th order ground temperature),
# /home/scratch01/gmiloshe/tests/qgs/qgs/params/parameter.py:106: UserWarning: Parameter configured to perform dimensional conversion but without specifying a ScaleParams object: Conversion disabled!
#   warnings.warn("Parameter configured to perform dimensional conversion " +

# %% [markdown]
# Why did Robin choose n = 0.353? Otherwise the setup is similar to ground_heat.ipynb but with more spectral components. It is not clear to me if we need many spectral components. The typical setup with fewer components is usually enough to provide some realism.
#
# Parameters that are different:
# * Atmospheric Temperature parameters
#     * 'C[1]' : 122 [W][m^-2] instead of 99 [W][m^-2]: (spectral component 1 of the short-wave radiation of the atmosphere), other C's are zero
#     * 'hlambda': 20  [W][m^-2][K^-1] instead of 10 [W][m^-2][K^-1] (sensible+turbulent heat exchange between ocean and atmosphere),
# * Ground Parameters:
#     * 'hk[2]': 0.4 instead of 0.2    (spectral components 2 of the orography), other h'k are zero
# * Ground Temperature Parameters:
#     * 'gamma': 200000000  [J][m^-2][K^-1] instead of 16000000  (specific heat capacity of the ground),
#     * 'C[1]': 280.0  [W][m^-2]  (spectral component 1 of the short-wave radiation of the ground), other C parameters are zero
#
# Below we can also investigate what fields that are actually used

# %%
model_parameters.latex_var_string
# Out:
# ['{\\psi_{\\rm a,1}}',
#  '{\\psi_{\\rm a,2}}',
#  '{\\psi_{\\rm a,3}}',
#  '{\\psi_{\\rm a,4}}',
#  '{\\psi_{\\rm a,5}}',
#  '{\\psi_{\\rm a,6}}',
#  '{\\psi_{\\rm a,7}}',
#  '{\\psi_{\\rm a,8}}',
#  '{\\psi_{\\rm a,9}}',
#  '{\\psi_{\\rm a,10}}',
#  '{\\psi_{\\rm a,11}}',
#  '{\\psi_{\\rm a,12}}',
#  '{\\psi_{\\rm a,13}}',
#  '{\\psi_{\\rm a,14}}',
#  '{\\psi_{\\rm a,15}}',
#  '{\\psi_{\\rm a,16}}',
#  '{\\psi_{\\rm a,17}}',
#  '{\\psi_{\\rm a,18}}',
#  '{\\psi_{\\rm a,19}}',
#  '{\\psi_{\\rm a,20}}',
#  '{\\psi_{\\rm a,21}}',
#  '{\\psi_{\\rm a,22}}',
#  '{\\psi_{\\rm a,23}}',
#  '{\\psi_{\\rm a,24}}',
#  '{\\psi_{\\rm a,25}}',
#  '{\\psi_{\\rm a,26}}',
#  '{\\psi_{\\rm a,27}}',
#  '{\\psi_{\\rm a,28}}',
#  '{\\psi_{\\rm a,29}}',
#  '{\\psi_{\\rm a,30}}',
#  '{\\psi_{\\rm a,31}}',
#  '{\\psi_{\\rm a,32}}',
#  '{\\psi_{\\rm a,33}}',
#  '{\\psi_{\\rm a,34}}',
#  '{\\psi_{\\rm a,35}}',
#  '{\\psi_{\\rm a,36}}',
#  '{\\theta_{\\rm a,1}}',
#  '{\\theta_{\\rm a,2}}',
#  '{\\theta_{\\rm a,3}}',
#  '{\\theta_{\\rm a,4}}',
#  '{\\theta_{\\rm a,5}}',
#  '{\\theta_{\\rm a,6}}',
#  '{\\theta_{\\rm a,7}}',
#  '{\\theta_{\\rm a,8}}',
#  '{\\theta_{\\rm a,9}}',
#  '{\\theta_{\\rm a,10}}',
#  '{\\theta_{\\rm a,11}}',
#  '{\\theta_{\\rm a,12}}',
#  '{\\theta_{\\rm a,13}}',
#  '{\\theta_{\\rm a,14}}',
#  '{\\theta_{\\rm a,15}}',
#  '{\\theta_{\\rm a,16}}',
#  '{\\theta_{\\rm a,17}}',
#  '{\\theta_{\\rm a,18}}',
#  '{\\theta_{\\rm a,19}}',
#  '{\\theta_{\\rm a,20}}',
#  '{\\theta_{\\rm a,21}}',
#  '{\\theta_{\\rm a,22}}',
#  '{\\theta_{\\rm a,23}}',
#  '{\\theta_{\\rm a,24}}',
#  '{\\theta_{\\rm a,25}}',
#  '{\\theta_{\\rm a,26}}',
#  '{\\theta_{\\rm a,27}}',
#  '{\\theta_{\\rm a,28}}',
#  '{\\theta_{\\rm a,29}}',
#  '{\\theta_{\\rm a,30}}',
#  '{\\theta_{\\rm a,31}}',
#  '{\\theta_{\\rm a,32}}',
#  '{\\theta_{\\rm a,33}}',
#  '{\\theta_{\\rm a,34}}',
#  '{\\theta_{\\rm a,35}}',
#  '{\\theta_{\\rm a,36}}',
#  '{\\theta_{\\rm g,1}}',
#  '{\\theta_{\\rm g,2}}',
#  '{\\theta_{\\rm g,3}}',
#  '{\\theta_{\\rm g,4}}',
#  '{\\theta_{\\rm g,5}}',
#  '{\\theta_{\\rm g,6}}',
#  '{\\theta_{\\rm g,7}}',
#  '{\\theta_{\\rm g,8}}',
#  '{\\theta_{\\rm g,9}}',
#  '{\\theta_{\\rm g,10}}',
#  '{\\theta_{\\rm g,11}}',
#  '{\\theta_{\\rm g,12}}',
#  '{\\theta_{\\rm g,13}}',
#  '{\\theta_{\\rm g,14}}',
#  '{\\theta_{\\rm g,15}}',
#  '{\\theta_{\\rm g,16}}',
#  '{\\theta_{\\rm g,17}}',
#  '{\\theta_{\\rm g,18}}',
#  '{\\theta_{\\rm g,19}}',
#  '{\\theta_{\\rm g,20}}',
#  '{\\theta_{\\rm g,21}}',
#  '{\\theta_{\\rm g,22}}',
#  '{\\theta_{\\rm g,23}}',
#  '{\\theta_{\\rm g,24}}',
#  '{\\theta_{\\rm g,25}}',
#  '{\\theta_{\\rm g,26}}',
#  '{\\theta_{\\rm g,27}}',
#  '{\\theta_{\\rm g,28}}',
#  '{\\theta_{\\rm g,29}}',
#  '{\\theta_{\\rm g,30}}',
#  '{\\theta_{\\rm g,31}}',
#  '{\\theta_{\\rm g,32}}',
#  '{\\theta_{\\rm g,33}}',
#  '{\\theta_{\\rm g,34}}',
#  '{\\theta_{\\rm g,35}}',
#  '{\\theta_{\\rm g,36}}']

# %% [markdown]
# Creating the tendencies function

# %%
# %%time
f, Df = create_tendencies(model_parameters)
# Out:
# CPU times: user 3min 26s, sys: 3.32 s, total: 3min 29s
# Wall time: 3min 26s

# %% [markdown]
# ## Time integration
# Defining an integrator

# %%
integrator = RungeKuttaIntegrator()
integrator.set_func(f)

# %% [markdown]
# Start on a random initial condition and integrate over a transient time to obtain an initial condition on the attractors. I kept the standard time that is typically used in other runs, so not sure if it perfectly adapted...

# %%
# %%time
ic = np.random.rand(model_parameters.ndim)*0.1
integrator.integrate(0., 200000., dt, ic=ic, write_steps=0)
time, ic = integrator.get_trajectories()
# Out:
# CPU times: user 25.7 ms, sys: 32.1 ms, total: 57.8 ms
# Wall time: 2min 9s

# %% [markdown]
# Now integrate to obtain a trajectory on the attractor

# %%
# %%time
integrator.integrate(0., 100000., dt, ic=ic, write_steps=write_steps)
reference_time, reference_traj = integrator.get_trajectories()
# Out:
# CPU times: user 264 ms, sys: 465 ms, total: 729 ms
# Wall time: 1min 3s

# %% [markdown]
# We can visualize the trajectories of individual harmonics in 3D

# %%
varx = 0
vary = 1
varz = 2

fig = plt.figure(figsize=(10, 8))
axi = fig.add_subplot(111, projection='3d')

axi.scatter(reference_traj[varx], reference_traj[vary], reference_traj[varz], s=0.2);

axi.set_xlabel('$'+model_parameters.latex_var_string[varx]+'$')
axi.set_ylabel('$'+model_parameters.latex_var_string[vary]+'$')
axi.set_zlabel('$'+model_parameters.latex_var_string[varz]+'$');

# %% [markdown]
# Also in 2D

# %%
varx = 2
vary = 1
plt.figure(figsize=(10, 8))

plt.plot(reference_traj[varx], reference_traj[vary], marker='o', ms=0.07, ls='')

plt.xlabel('$'+model_parameters.latex_var_string[varx]+'$')
plt.ylabel('$'+model_parameters.latex_var_string[vary]+'$');

# %% [markdown]
# And even 1D

# %%
var = 1
plt.figure(figsize=(10, 8))

plt.plot(model_parameters.dimensional_time*reference_time, reference_traj[var])

plt.xlabel('time (days)')
plt.ylabel('$'+model_parameters.latex_var_string[var]+'$');

# %% [markdown]
# ## Initial condition sensitivity analysis example
# Instantiating a tangent linear integrator with the model tendencies

# %%
tgls_integrator = RungeKuttaTglsIntegrator()
tgls_integrator.set_func(f, Df)

# %% [markdown]
# Integrating with slightly perturbed initial conditions

# %%
# %%time 
tangent_ic = 0.0001*np.random.randn(number_of_perturbed_trajectories, model_parameters.ndim)
tgls_integrator.integrate(0., 150., dt=dt, write_steps=write_steps, ic=ic, tg_ic=tangent_ic)
# Out:
# CPU times: user 4.21 ms, sys: 16 ms, total: 20.2 ms
# Wall time: 10.1 s

# %% [markdown]
# Obtaining the perturbed trajectories

# %%
time, traj, delta = tgls_integrator.get_trajectories()
pert_traj = traj + delta

# %% [markdown]
# Trajectories plot

# %%
var = 10
plt.figure(figsize=(10, 8))

plt.plot(model_parameters.dimensional_time*time, traj[var])
plt.plot(model_parameters.dimensional_time*time, pert_traj[:,var].T, ls=':')

ax = plt.gca()

plt.xlabel('time (days)')
plt.ylabel('$'+model_parameters.latex_var_string[var]+'$');

# %% [markdown]
# Mean and standard deviation

# %%
var = 1
plt.figure(figsize=(10, 8))

plt.plot(model_parameters.dimensional_time*time, traj[var])

ax = plt.gca()
std_plot(model_parameters.dimensional_time*time, np.mean(pert_traj[:,var], axis=0), np.sqrt(np.var(pert_traj[:, var], axis=0)), ax=ax, alpha=0.5)

plt.xlabel('time (days)')
plt.ylabel('$'+model_parameters.latex_var_string[var]+'$');

# %% [markdown]
# ## Showing the resulting fields (animation)
#
# This is an advanced feature showing the time evolution of diagnostic of the model. It shows simultaneously a scatter plot of the variable $\psi_2$ and $\psi_3$, and the geopotential height field at 500 hPa over the orographic height. Please read the documentation for more information.
#
# Creating the diagnostics:
# * For the 500hPa geopotential height:

# %%
psi = MiddleAtmosphericStreamfunctionDiagnostic(model_parameters, geopotential=True)

# %% [markdown]
# * For the nondimensional variables $\psi_2$ and $\psi_3$:

# %%
variable_nondim = VariablesDiagnostic([2, 1], model_parameters, False)

# %% [markdown]
# setting also the background

# %%
background = VariablesDiagnostic([2, 1], model_parameters, False)
background.set_data(reference_time, reference_traj)

# %% [markdown]
# Creating a multi diagnostic with both:

# %%
m = MultiDiagnostic(1,2)
m.add_diagnostic(variable_nondim,
                 diagnostic_kwargs={'show_time': False, 'background': background},
                 plot_kwargs={'ms': 0.2})
m.add_diagnostic(psi,
                 diagnostic_kwargs={'style': 'contour', 'contour_labels': False},
                 plot_kwargs={'colors': 'k'})
m.set_data(time, traj)

# %% [markdown]
# and show an interactive animation:

# %%
rc('font',**{'family':'serif','sans-serif':['Times'],'size':12})
m.animate(figsize=(20,6))
# Out:
# interactive(children=(IntSlider(value=150, description='time_index', max=300), Output()), _dom_classes=('widge…

# %% [markdown]
# We can also quickly plot the snapshot of geopotential at a given time

# %%
psi.plot(0, plot_kwargs={'vmin' : -1000, 'vmax' :1000})
# Out:
# (<AxesSubplot:title={'center':'Atmospheric 500hPa geopotential height (in m) at 0.00 days'}, xlabel='$x$', ylabel='$y$'>,
#  <matplotlib.colorbar.Colorbar at 0x2aff2dc33d90>)

# %% [markdown]
# Or make a short movie

# %%
psi.movie(figsize=(13,8), anim_kwargs={'interval': 100, 'frames':100})
# Out:
# <video width="1300" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# Here we show how to extract ndarray from diagnostics (had to look inside the code on GitHub, otherwise tutorials do not cover this). I am comparing the diagnostic plots with my own plots where I extract the ndarray myself. There is a layer of interpolation that I am missing, but that's ok

# %%
cs = plt.contourf(psi._X, psi._Y, psi.diagnostic[0,...], cmap="gist_rainbow_r", levels=100, vmin=-1000, vmax=1000)
plt.colorbar(cs)
plt.axis('equal')
psi.plot(0, plot_kwargs={'vmin' : -1000, 'vmax' :1000})
# Out:
# (<AxesSubplot:title={'center':'Atmospheric 500hPa geopotential height (in m) at 0.00 days'}, xlabel='$x$', ylabel='$y$'>,
#  <matplotlib.colorbar.Colorbar at 0x2aff2f816280>)

# %% [markdown]
# Just to show that at a later time we still get the correct field

# %%
cs = plt.contourf(psi._X, psi._Y, psi.diagnostic[10,...], cmap="gist_rainbow_r", levels=100, vmin=-1000, vmax=1000)
plt.colorbar(cs)
psi.plot(10, plot_kwargs={'vmin' : -1000, 'vmax' :1000})
# Out:
# (<AxesSubplot:title={'center':'Atmospheric 500hPa geopotential height (in m) at 0.56 days'}, xlabel='$x$', ylabel='$y$'>,
#  <matplotlib.colorbar.Colorbar at 0x2aff2eff2b80>)

# %%
from qgs.diagnostics.variables import GeopotentialHeightDifferenceDiagnostic

# %% [markdown]
# For the geopotential height difference between North and South:

# %%
geopot_dim = GeopotentialHeightDifferenceDiagnostic([[[np.pi/model_parameters.scale_params.n, np.pi/4], [np.pi/model_parameters.scale_params.n, 3*np.pi/4]]],
                                                    model_parameters, True)

# %% [markdown]
# Creating a multi diagnostic for just this one variable. Maybe this is not optimal?

# %%
m = MultiDiagnostic(1,1)
m.add_diagnostic(geopot_dim, diagnostic_kwargs={'style':'timeserie'})
m.set_data(time, traj)

# %% [markdown]
# Making a movie

# %%
# %%time
rc('font',**{'family':'serif','sans-serif':['Times'],'size':12})
m.plot(figsize=(20,6), time_index=0)
# Out:
# CPU times: user 34.3 ms, sys: 7.89 ms, total: 42.2 ms
# Wall time: 35.8 ms

# %% [markdown]
# We are actually interested in the ground temperature. The following is stated in the References:
#
# Diagnostic giving the ground temperature anomaly fields

# %%
from qgs.diagnostics.temperatures import GroundTemperatureDiagnostic

groundT = GroundTemperatureDiagnostic(model_parameters, True)

# %%
m = MultiDiagnostic(1,1)
m.add_diagnostic(groundT,
                 diagnostic_kwargs={'style': 'contour', 'contour_labels': False},
                 plot_kwargs={'colors': 'k'})
m.set_data(time, traj)

# %%
rc('font',**{'family':'serif','sans-serif':['Times'],'size':12})
m.animate(figsize=(20,6))
# Out:
# interactive(children=(IntSlider(value=130, description='time_index', max=260), Output()), _dom_classes=('widge…

# %% [markdown]
# Actually there is a much better way to do this

# %%
groundT = GroundTemperatureDiagnostic(model_parameters, True)

# %% [markdown]
# and feed it with a model outputs time and trajectory previously computed

# %%
groundT.set_data(time, traj)

# %%
groundT.plot(10)
# Out:
# (<AxesSubplot:title={'center':'Ground temperature anomaly (in K) at 0.56 days'}, xlabel='$x$', ylabel='$y$'>,
#  <matplotlib.colorbar.Colorbar at 0x2aff18d1b400>)
